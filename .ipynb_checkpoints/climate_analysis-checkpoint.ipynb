# %%
import pandas as pd

# %%
# Import Matplot lib and use the `nbagg` backend

import matplotlib
matplotlib.use('nbagg')
from matplotlib import style
style.use('seaborn')
import matplotlib.pyplot as plt

# %%
 # Import SQLAlchemy `automap` and other dependencies here
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, inspect, func

# %%
 # Create an engine for the `emoji.sqlite` database
engine = create_engine("sqlite:///hawaii.sqlite", echo=False)

# %% [markdown]
# # Explore database

# %%
# Use the Inspector to explore the database and print the table names
inspector = inspect(engine)
inspector.get_table_names()
# Out:
# ['measurements', 'stations']

# %%
# Use Inspector to print the column names and types
columns = inspector.get_columns('measurements')
for c in columns:
    print(c['name'], c["type"])
# Out:
# id INTEGER
# station TEXT
# date VARCHAR(10)
# prcp FLOAT
# tobs FLOAT

# %%
# Use Inspector to print the column names and types
columns = inspector.get_columns('stations')
for c in columns:
    print(c['name'], c["type"])
# Out:
# station TEXT
# name VARCHAR(50)
# latitude FLOAT
# longitude FLOAT
# elevation FLOAT

# %%
 # Use `engine.execute` to select and display the first 10 rows from each table
engine.execute('SELECT * FROM stations LIMIT 10').fetchall()
# Out:
# [('USC00519397', 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0),
#  ('USC00513117', 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  ('USC00514830', 'KUALOA RANCH HEADQUARTERS 886.9, HI US', 21.5213, -157.8374, 7.0),
#  ('USC00517948', 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9),
#  ('USC00518838', 'UPPER WAHIAWA 874.3, HI US', 21.4992, -158.0111, 306.6),
#  ('USC00519523', 'WAIMANALO EXPERIMENTAL FARM, HI US', 21.33556, -157.71139, 19.5),
#  ('USC00519281', 'WAIHEE 837.5, HI US', 21.45167, -157.84888999999998, 32.9),
#  ('USC00511918', 'HONOLULU OBSERVATORY 702.2, HI US', 21.3152, -157.9992, 0.9),
#  ('USC00516128', 'MANOA LYON ARBO 785.2, HI US', 21.3331, -157.8025, 152.4)]

# %%
engine.execute('SELECT * FROM measurements limit 10').fetchall()
# Out:
# [(1, 'USC00519397', '2010-01-01', 0.08, 65.0),
#  (2, 'USC00519397', '2010-01-02', 0.0, 63.0),
#  (3, 'USC00519397', '2010-01-03', 0.0, 74.0),
#  (4, 'USC00519397', '2010-01-04', 0.0, 76.0),
#  (5, 'USC00519397', '2010-01-06', None, 73.0),
#  (6, 'USC00519397', '2010-01-07', 0.06, 70.0),
#  (7, 'USC00519397', '2010-01-08', 0.0, 64.0),
#  (8, 'USC00519397', '2010-01-09', 0.0, 68.0),
#  (9, 'USC00519397', '2010-01-10', 0.0, 73.0),
#  (10, 'USC00519397', '2010-01-11', 0.01, 64.0)]

# %% [markdown]
# # Reflect database and Query

# %%
# Reflect Database into ORM class
Base = automap_base()
Base.prepare(engine, reflect=True)
Station = Base.classes.stations

# %%
Base = automap_base()
Base.prepare(engine, reflect=True)
Measurement = Base.classes.measurements

# %%
 # Start a session to query the database
session = Session(engine)

# %% [markdown]
# # Precipitation Analysis

# %%
max_date=session.query(func.max(Measurement.date)).all()
max_date
# Out:
# [('2017-08-23')]

# %%
# Based on max data of precipitation data, we are going to obtain last 12 months of data

results = session.query(Measurement.date, Measurement.prcp).filter(Measurement.date >='2016-09-01').\
filter(Measurement.prcp != None).\
order_by(Measurement.date.desc()).all()

results
# Out:
# [('2017-08-23', 0.0),
#  ('2017-08-23', 0.0),
#  ('2017-08-23', 0.08),
#  ('2017-08-23', 0.45),
#  ('2017-08-22', 0.0),
#  ('2017-08-22', 0.0),
#  ('2017-08-22', 0.5),
#  ('2017-08-21', 0.0),
#  ('2017-08-21', 0.02),
#  ('2017-08-21', 0.56),
#  ('2017-08-20', 0.0),
#  ('2017-08-20', 0.01),
#  ('2017-08-19', 0.0),
#  ('2017-08-19', 0.0),
#  ('2017-08-19', 0.09),
#  ('2017-08-18', 0.0),
#  ('2017-08-18', 0.0),
#  ('2017-08-18', 0.06),
#  ('2017-08-17', 0.0),
#  ('2017-08-17', 0.05),
#  ('2017-08-17', 0.01),
#  ('2017-08-17', 0.13),
#  ('2017-08-16', 0.0),
#  ('2017-08-16', 0.07),
#  ('2017-08-16', 0.12),
#  ('2017-08-16', 0.42),
#  ('2017-08-15', 0.02),
#  ('2017-08-15', 0.0),
#  ('2017-08-15', 0.06),
#  ('2017-08-15', 0.32),
#  ('2017-08-15', 0.42),
#  ('2017-08-14', 0.0),
#  ('2017-08-14', 0.01),
#  ('2017-08-14', 0.08),
#  ('2017-08-14', 0.0),
#  ('2017-08-14', 0.22),
#  ('2017-08-13', 0.0),
#  ('2017-08-13', 0.0),
#  ('2017-08-13', 0.0),
#  ('2017-08-12', 0.0),
# ...

# %%
len(results)
# Out:
# 1968

# %%
df_prcp = pd.DataFrame(results, columns=['date', 'prcp'])

# %%
#Plot the data
prcp_plot = df_prcp.plot('date', 'prcp')
plt.xlabel('date')
plt.setp(prcp_plot.xaxis.get_label(), visible=True, text='Dates')
plt.ylabel('Precipitation \n (In Inches)')
plt.title('Hawaii Preciptiation Analysis \n (8/23/2017 - Last 12 months)')
plt.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="799.9999682108573">

# %% [markdown]
# # Station Analysis

# %%
#Design a query to calculate the total number of stations.

Total_number_stations=session.query(Station.station).count()
print(f"Total number stations: {Total_number_stations}")
# Out:
# Total number stations: 9

# %%
data_stations=session.query(Measurement.station, func.count(Measurement.tobs)).\
group_by(Measurement.station).order_by(func.count(Measurement.tobs).desc()).all()

data_stations
# Out:
# [('USC00519281', 2772),
#  ('USC00519397', 2724),
#  ('USC00513117', 2709),
#  ('USC00519523', 2669),
#  ('USC00516128', 2612),
#  ('USC00514830', 2202),
#  ('USC00511918', 1979),
#  ('USC00517948', 1372),
#  ('USC00518838', 511)]

# %%
print(f"Station which has the highest number of observations: {data_stations[0]}")
# Out:
# Station which has the highest number of observations: ('USC00519281', 2772)

# %%
# Based on max data of temperature data, we are going to obtain last 12 months of data

results_tobs = session.query(Measurement.date, Measurement.tobs).filter(Measurement.date >='2016-09-01').\
filter(Measurement.tobs != None).\
filter(Measurement.station == 'USC00519281').\
order_by(Measurement.date.desc()).all()

results_tobs
# Out:
# [('2017-08-18', 79.0),
#  ('2017-08-17', 76.0),
#  ('2017-08-16', 76.0),
#  ('2017-08-15', 77.0),
#  ('2017-08-14', 77.0),
#  ('2017-08-13', 77.0),
#  ('2017-08-06', 83.0),
#  ('2017-08-05', 82.0),
#  ('2017-08-04', 77.0),
#  ('2017-07-31', 76.0),
#  ('2017-07-30', 81.0),
#  ('2017-07-29', 82.0),
#  ('2017-07-28', 81.0),
#  ('2017-07-27', 76.0),
#  ('2017-07-26', 75.0),
#  ('2017-07-25', 77.0),
#  ('2017-07-24', 75.0),
#  ('2017-07-23', 82.0),
#  ('2017-07-22', 77.0),
#  ('2017-07-21', 77.0),
#  ('2017-07-20', 77.0),
#  ('2017-07-19', 76.0),
#  ('2017-07-18', 76.0),
#  ('2017-07-17', 76.0),
#  ('2017-07-16', 80.0),
#  ('2017-07-15', 80.0),
#  ('2017-07-14', 76.0),
#  ('2017-07-13', 74.0),
#  ('2017-07-12', 74.0),
#  ('2017-07-11', 72.0),
#  ('2017-07-10', 69.0),
#  ('2017-07-09', 78.0),
#  ('2017-07-08', 78.0),
#  ('2017-07-07', 75.0),
#  ('2017-07-06', 74.0),
#  ('2017-07-05', 77.0),
#  ('2017-07-04', 78.0),
#  ('2017-07-03', 76.0),
#  ('2017-07-02', 81.0),
#  ('2017-07-01', 79.0),
# ...

# %% [markdown]
# # Temperature Analysis

# %%
#Write a function called calc_temps that will accept a start date and end date in the format %Y-%m-%d 
#and return the minimum, average, and maximum temperatures for that range of dates.

def calc_temps(start_date,end_date):
    
    sel = [func.max(Measurement.tobs),func.min(Measurement.tobs),func.avg(Measurement.tobs)]
    
    results_calc_temps = session.query(*sel).\
    filter(func.strftime("%Y-%m-%dm", Measurement.date) >= start_date).\
    filter(func.strftime("%Y-%m-%dm", Measurement.date) <= end_date).all()
        

    return results_calc_temps

calc_temps('2016-04-15','2017-01-15')
# Out:
# [(84.0, 60.0, 75.26655152561888)]
